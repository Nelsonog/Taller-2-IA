# %% [markdown]
# ![itm_logo.jpg](attachment:itm_logo.jpg)
#
# <h2>Inteligencia Artificial - IAI84</h2>
#
# <h3>Instituto Tecnológico Metropolitano</h3>
# Pedro Atencio Ortiz - 2018
# <br>
#
#
# <strong><h2>Punto 3. </h2></strong>
#
# Aplicar el método de selección por RULETA para todos los problemas del taller y evaluar respecto a la implementación del punto 1 respecto a los siguientes criterios:
# <br>
# 3.1. Convergencia:
# <br>
# ¿En promedio, utilizando RULETA se disminuye o aumenta el número de epocas necesarias para que el algoritmo se estabilice?
# <br<
# 3.2. Efectividad:
# <br>
# ¿En promedio, RULETA permite obtener la mejor solución de forma repetida?
#
# <br>

# %% [markdown]
# * En los problemas de la mochila se obtuvieron mejores resultados utilizando el metodo de la Ruleta, aun que el metodo del random mostraba mejores resultados en algunas ocaciones, pero predominó el método de la ruleta en la mayoria de las ocacioes.
#
# <table>
#     <tr>
#         <td>
#             <p><h2>Randon</h2>
#         </td>
#         <td>
#             <p><h2>Ruleta</h2>
#         </td>
#     </tr>
#     <tr >
#         <td>
#             ![p1%20mochila%20Randon.png](attachment:p1%20mochila%20Randon.png)
#         </td>
#         <td>
#              ![p1%20mochila%20Ruleta.png](attachment:p1%20mochila%20Ruleta.png)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <p>![p2%20mochila%20Randon.png](attachment:p2%20mochila%20Randon.png)
#         </td>
#         <td>
#             <p>![p2%20mochila%20Ruleta.png](attachment:p2%20mochila%20Ruleta.png)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <p>![p3%20mochila%20Randon.png](attachment:p3%20mochila%20Randon.png)
#         </td>
#         <td>
#             <p>![p3%20mochila%20Ruleta.png](attachment:p3%20mochila%20Ruleta.png)
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <p>![p4%20mochila%20Randon.png](attachment:p4%20mochila%20Randon.png)
#         </td>
#         <td>
#             <p>![p4%20mochila%20Ruleta.png](attachment:p4%20mochila%20Ruleta.png)
#         </td>
#     </tr>
#
#
#
#
# <br>
#
#
# <br>
#
#
#
# <br>
#
#
#
# <br>

# %% [markdown]
# * En el Problema del Viajero se pudo evidenciar un mejoramiento en la opcion del randon contra la opcion de laruleta al incrementar la iteraciones en ambos ejercicios, es recomendable usar un gran numero de iteracion si se desa usar la opcion del random, mientras que la opcion de la ruleta es mejor en funcion de aptitud al usar un numero pequeño de iteraciones.
#
# <br>
# <table>
#   <tr>
#     <td></td> <td>Random</td> <td>Ruleta</td>
#   </tr>
#   <tr>
#     <td>10 iteraciones</td>
#     <td>![viajero%20random%20baja.png](attachment:viajero%20random%20baja.png)</td>
#     <td>![viajero%20ruleta%20baja.png](attachment:viajero%20ruleta%20baja.png)</td>
#   </tr>
#   <tr>
#     <td>5000 iteraciones</td>
#     <td>![viajero%20random%20alto.png](attachment:viajero%20random%20alto.png)</td>
#     <td>![viajero%20ruleta%20alto.png](attachment:viajero%20ruleta%20alto.png)</td>
#
# </table>

# %% [markdown]
# <br>
#
# En ambos caso se nota una mejora al incrementar las iteraciones y se evidencia en los gráficos creados.
# <br>
# a continuacion se muestra la tabla con un numero de iteraciones de 5000 en el problema del viajero
# <br>
#
#
# <table>
#   <tr>
#     <td style="text-align: center;">Intento</td>
#     <td style="text-align: center;">Random</td>
#     <td style="text-align: center;">Ruleta</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">1</td>
#     <td style="text-align: center;"> 0.02492503510674533</td>
#     <td style="text-align: center;">0.01855987609786127</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">2</td>
#     <td style="text-align: center;"> 0.015434953339965446</td>
#     <td style="text-align: center;">0.02492503510674534</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">3</td>
#     <td style="text-align: center;"> 0.02263754789219177</td>
#     <td style="text-align: center;">0.019131000616063328</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">4</td>
#     <td style="text-align: center;"> 0.02263754789219177</td>
#     <td style="text-align: center;"> 0.015608813939895431</td>
#   </tr>
#   <tr>
#     <td style="text-align: center;">5</td>
#     <td style="text-align: center;"> 0.020297961424245815</td>
#     <td style="text-align: center;">0.019897726639305547</td>
#   </tr>
# </table>
